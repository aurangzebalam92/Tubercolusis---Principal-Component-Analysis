# %% [markdown]
# # Principal of analysis for tubercolusis_from 2007_WHO

# %%
# import libraries
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
# set the working directory
os.chdir("E:/Data Science/Data Science/Edureka/Case Studies/4. TB prevelance")

# %%
#  check the working directory
os.getcwd()
# Out:
# 'E:\\Data Science\\Data Science\\Edureka\\Case Studies\\4. TB prevelance'

# %%
# load the data
Dua = pd.read_csv("tubercolusis_from 2007_WHO.csv",index_col=0)

# %%
#top 5 rows of the dataset
Dua.head()
# Out:
#              Year Number of deaths due to tuberculosis, excluding HIV  \
# Country
# Afghanistan  2014                                            14 000
# Afghanistan  2013                                            13 000
# Afghanistan  2012                                            12 000
# Afghanistan  2011                                            11 000
# Afghanistan  2010                                            11 000
#
#             Number of deaths due to tuberculosis, excluding HIV (Start range)  \
# Country
# Afghanistan                                             10 000
# Afghanistan                                              9 300
# Afghanistan                                              8 700
# Afghanistan                                              8 300
# Afghanistan                                              8 000
#
#             Number of deaths due to tuberculosis, excluding HIV (End range)  \
# Country
# ...

# %%
#shape of the data
Dua.shape
# Out:
# (1548, 13)

# %%
#no. of columns
Dua.columns
# Out:
# Index(['Year', 'Number of deaths due to tuberculosis, excluding HIV',
#        'Number of deaths due to tuberculosis, excluding HIV (Start range)',
#        'Number of deaths due to tuberculosis, excluding HIV (End range)',
#        'Number of prevalent tuberculosis cases',
#        'Number of prevalent tuberculosis cases (Start range)',
#        'Number of prevalent tuberculosis cases (End range)',
#        'Deaths due to tuberculosis among HIV-negative people (per 100 000 population)',
#        'Deaths due to tuberculosis among HIV-negative people (per 100 000 population) (Start range)',
#        'Deaths due to tuberculosis among HIV-negative people (per 100 000 population) (End range)',
#        'Prevalence of tuberculosis (per 100 000 population)',
#        'Prevalence of tuberculosis (per 100 000 population)(start range)',
#        'Prevalence of tuberculosis (per 100 000 population)(end range)'],
#       dtype='object')

# %%
Dua.dtypes
# Out:
# Year                                                                                             int64
# Number of deaths due to tuberculosis, excluding HIV                                             object
# Number of deaths due to tuberculosis, excluding HIV (Start range)                               object
# Number of deaths due to tuberculosis, excluding HIV (End range)                                 object
# Number of prevalent tuberculosis cases                                                          object
# Number of prevalent tuberculosis cases (Start range)                                            object
# Number of prevalent tuberculosis cases (End range)                                              object
# Deaths due to tuberculosis among HIV-negative people (per 100 000 population)                  float64
# Deaths due to tuberculosis among HIV-negative people (per 100 000 population) (Start range)    float64
# ...

# %%
Dua["Number of deaths due to tuberculosis, excluding HIV"] = Dua["Number of deaths due to tuberculosis, excluding HIV"].convert_objects(convert_numeric=True)
Dua["Number of deaths due to tuberculosis, excluding HIV (Start range)"] = Dua["Number of deaths due to tuberculosis, excluding HIV (Start range)"].convert_objects(convert_numeric=True)
Dua["Number of deaths due to tuberculosis, excluding HIV (End range)"] = Dua["Number of deaths due to tuberculosis, excluding HIV (End range)"].convert_objects(convert_numeric=True)
Dua["Number of prevalent tuberculosis cases"] = Dua["Number of prevalent tuberculosis cases"].convert_objects(convert_numeric=True)
Dua["Number of prevalent tuberculosis cases (Start range)"] = Dua["Number of prevalent tuberculosis cases (Start range)"].convert_objects(convert_numeric=True)
Dua["Number of prevalent tuberculosis cases (End range)"] = Dua["Number of prevalent tuberculosis cases (End range)"].convert_objects(convert_numeric=True)
Dua["Prevalence of tuberculosis (per 100 000 population)"] = Dua["Prevalence of tuberculosis (per 100 000 population)"].convert_objects(convert_numeric=True)
Dua["Prevalence of tuberculosis (per 100 000 population)(end range)"] = Dua["Prevalence of tuberculosis (per 100 000 population)(end range)"].convert_objects(convert_numeric=True)
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use Series.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use Series.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use Series.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# ...

# %%
Dua.dtypes
# Out:
# Year                                                                                             int64
# Number of deaths due to tuberculosis, excluding HIV                                            float64
# Number of deaths due to tuberculosis, excluding HIV (Start range)                              float64
# Number of deaths due to tuberculosis, excluding HIV (End range)                                float64
# Number of prevalent tuberculosis cases                                                         float64
# Number of prevalent tuberculosis cases (Start range)                                           float64
# Number of prevalent tuberculosis cases (End range)                                             float64
# Deaths due to tuberculosis among HIV-negative people (per 100 000 population)                  float64
# Deaths due to tuberculosis among HIV-negative people (per 100 000 population) (Start range)    float64
# ...

# %%
missing_value = Dua.isnull().sum().sum()
missing_value
# Out:
# 4901

# %%
Dua = Dua.fillna(Dua.mean())

# %%
missing_value2 = Dua.isnull().sum().sum()
missing_value2
# Out:
# 0

# %%
#Correlation
plt.figure(figsize=(10,10))
sns.heatmap(Dua.corr(),square=True,annot=True)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=3)

# %%
pca.fit(Dua)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=3, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
Dua1 = pca.transform(Dua)

# %%
Dua2 = pd.DataFrame(Dua1)

# %%
Dua2.index = Dua.index

# %%
Dua2.columns = ["Zahra","Tinku","Adam"]

# %%
Dua2.head()
# Out:
#                   Zahra       Tinku      Adam
# Country
# Afghanistan  254.186922 -278.935499 -1.314915
# Afghanistan  243.700652 -267.408976 -1.255857
# Afghanistan  238.947861 -262.297825 -1.225664
# Afghanistan  235.005416 -257.897718 -1.202812
# Afghanistan  232.932367 -255.688769 -1.194340

# %%
#Eigen vector and Eigen values
pca.explained_variance_ratio_
# Out:
# array([0.38834715, 0.24919429, 0.16067103])

# %%
pca.score
# Out:
# <bound method PCA.score of PCA(copy=True, iterated_power='auto', n_components=3, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)>
